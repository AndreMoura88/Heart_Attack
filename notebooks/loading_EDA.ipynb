# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreMoura88/Heart_Attack/blob/main/notebooks/loading_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Health care: Heart attack possibility
#
# Esse é um banco de dados de Cleveland, o qual foi o único usado por pesquisadores de ML até hoje. A variável target refere-se a presença de cardiopatia no paciente. Indicando se o paciente tem menos (0) ou mais (1) chance de ter um ataque cardíaco. (Fonte: Kaggle.com)
#
# ---
#
# *This is a database from Cleveland, which is the only database used by ML researchers to date. The target variable refers to the presence of heart disease in the patient. Indicating whether the patient has less (0) or more (1) chance of having a heart attack. (Source: Kaggle.com)*

# %% [markdown]
# # Análise exploratória
#
# ---
# *EDA*

# %% [markdown]
# ## Instalando/atualizando bibliotecas.
# Reiciniando o "runtime" e importando bibliotecas para tratamento dos dados. Esta etapa é importante para atualizar a versão do matplotlib, habilitando alguns recursos inesistentes na versão atual do Colab.
#
# ---
#
# ## *Installing/updating libraries*
# *Restarting the "runtime" and importing libraries for data processing. This step is important to update the matplotlib version, enabling some features not available in the current version of Colab.*
#
# ---

# %%
from IPython.display import clear_output 

#update matplotlib
# !pip install matplotlib --upgrade
clear_output()
# !pip install scipy --upgrade
clear_output()
import os
os.kill(os.getpid(), 9)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# importing some libraries
# bibliotecas
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

plt.style.use('ggplot')

import seaborn as sns

from plotly.offline import init_notebook_mode, iplot
from plotly import tools
import plotly.figure_factory as ff
import plotly.graph_objs as go
import plotly

# %%
# Importando datasets/ Dataset importing
df_heart = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Heart_attack/datasets/raw_data/heart.csv')

# %% [markdown]
# ## Sobre o dataset
# ---
# *About the dataset*

# %% [markdown]
# Informações sobre a base de dados<br>
# *About this dataset*
# <br>
#
# Para melhor acompanhamento das variáveis serão modificados seus nomes (o título terá uma preferência pelo idioma português) <br>
# *For better monitoring of the variables, their names will be modified (the title will have a preference for the Portuguese language)*
# <br>
#
# 1. ```age``` <br>
# Idade do paciente / *Age of the patient*
# <br>
#
# 2. ```sex```<br>
# Sexo do paciente/ *Sex of the patient*
# * 0 = feminino/ *female*
# * 1 = masculino/ *male*
# <br>
#
# 3. ```tipo_de_dor```<br>
#  Tipo de dor no peito/ *Chest Pain type*<br>
#  Angina é o nome dado para a dor no peito causada pela diminuição do fluxo de sangue no coração.
#  <br> *Angina is the name given to chest pain caused by decreased blood flow to the heart.*
# * 0 = assintomático/ *asymptomatic*
# * 1 = angina típica/ *typical angina*
# * 2 = angina atípica/ *atypical angina*
# * 3 = sem dor angina/ *non-anginal pain*
# <br>
#
# 4. ```pres_art_repous```<br>
# Pressão arterial em repouso / *resting blood pressure (in mm Hg)*
# <br>
#
# 5. ```colest```<br>
# Colesterol em mg/dl obtido via sensor de IMC / *cholestoral in mg/dl fetched via BMI sensor*
# <br>
#
# 6. ```acuc_sang_jejum```<br>
#  Açúcar no sangue em jejum > 120 mg/dl / *fasting blood sugar > 120 mg/dl*
# * 0 = Falso/ *False*
# * 1 = Verdadeiro / *True*
# <br>
#
# 7. ```eletrc_desc```<br>
# Resultados eletrocardiográficos em repouso / *resting electrocardiographic results*
# * 0 = hypertrophy,  mostrando hipertrofia ventricular esquerda provável ou definitiva pelos critérios de Estes / *showing probable or definite left ventricular hypertrophy by Estes' criteria*
# * 1 = normal;
# * 2 = tendo anormalidade da onda ST-T (inversões da onda T e/ou elevação ou depressão ST > 0,05 mV) / *having ST-T wave abnormality, (T wave inversions and/or ST elevation or depression of > 0.05 mV)*
# <br>
#
# 8. ```max_frq_card```<br>
# Frequência cardíaca máxima alcançada / *maximum heart rate achieved*
# <br>
#
# 9. ```ang_indz_exerc```<br>
# angina induzida por exercício / *exercise induced angina*
# * 0 = Não/ *No*
# * 1 = Sim/ *Yes*
# <br>
#
# 10. ```ST_indz_exerc```<br>
# Depressão de ST induzida por exercício em relação ao repouso / *ST depression induced by exercise relative to rest*
# <br>
#
# 11. ```pico_ST_exerc```<br>
# A inclinação do pico do segmento ST do exercício / *the slope of the peak exercise ST segment*
# * 0 = ascendente/ *upsloping*
# * 1 = plano /*flat*
# * 2 = descendente/ *downsloping*
# <br>
#
# 12. ```num_vasos```<br>
# número de vasos principais  (0-3) / *number of major vessels*
# <br>
#
# 13. ```talassemia```<br>
# talassemia (uma forma de anemia crônica)/ *thalassemia*
# * 1 = fixed defect
# * 2 = normal
# * 3 = reversable defect
# <br>
#
# 14. ```output``` :
# * 0 = menos chance de um ataque do coração / *less chance of heart attack*<br>
# * 1 = maior chance de um ataque do coração / *more chance of heart attack*

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Pandas

# %%
df_heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
# renomeando as colunas
# renaming the columns
df_heart = df_heart.rename(columns={'cp': 'tipo_de_dor', 'trtbps':'pres_art_repous', \
                                    'chol':'colest', 'fbs':'acuc_sang_jejum', \
                                    'restecg':'eletrc_desc', 'thalachh':'max_frq_card', \
                                    'exng':'ang_indz_exerc', 'oldpeak':'ST_indz_exerc', \
                                    'slp':'pico_ST_exerc', 'caa':'num_vasos', 'thall':'talassemia'
                                    }
                           )
# removendo linha duplicada
# Drop duplicates rows
df_heart = df_heart.drop_duplicates()

# %%
# verificando valores nulos ou missings
# checking for null or missing values
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              302 non-null    int64
#  1   sex              302 non-null    int64
#  2   tipo_de_dor      302 non-null    int64
#  3   pres_art_repous  302 non-null    int64
#  4   colest           302 non-null    int64
#  5   acuc_sang_jejum  302 non-null    int64
#  6   eletrc_desc      302 non-null    int64
#  7   max_frq_card     302 non-null    int64
#  8   ang_indz_exerc   302 non-null    int64
#  9   ST_indz_exerc    302 non-null    float64
#  10  pico_ST_exerc    302 non-null    int64
#  11  num_vasos        302 non-null    int64
#  12  talassemia       302 non-null    int64
#  13  output           302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %% [markdown]
# Dataset não contém valores nulos e todos os valores são numéricos. Atenção as colunas que contém valores categóricos, já como numéricos.<br>
#
# *Dataset does not contain null values and all values are numeric. Pay attention to the columns that contain categorical values, as numeric values.*
#
# ---

# %%
#Verificando as variáveis categóricas/ Checking categorical variables
df_heart.nunique().sort_values()
# Out:
# sex                  2
# acuc_sang_jejum      2
# ang_indz_exerc       2
# output               2
# eletrc_desc          3
# pico_ST_exerc        3
# tipo_de_dor          4
# talassemia           4
# num_vasos            5
# ST_indz_exerc       40
# age                 41
# pres_art_repous     49
# max_frq_card        91
# colest             152
# dtype: int64

# %% [markdown]
# A partir da análise dos tipos de dados para esse dataset foi feita uma investigação se os tipos usado foram os melhores.
# Usando o report_on_daframe do dtype_diet.
#
# *Based on the analysis of the data types for this dataset, an investigation was carried out to determine whether the types used were the best.
# Using report_on_daframe from dtype_diet.*

# %%
#Instalando a biblioteca/ installing package
! pip install dtype-diet

#Importando/ import
from dtype_diet import report_on_dataframe
from dtype_diet import optimize_dtypes # modificar o tipo das features/ modify the type of features

from IPython.display import clear_output
clear_output()

# %% [markdown]
# Verificando o tipo atual e conferindo a sugestão da biblioteca.
#
# *Checking the current type and checking the library suggestion*

# %%
report_on_dataframe(df_heart)
# Out:
#                 Current dtype Proposed dtype  Current Memory (MB)  \
# Column
# age                     int64           int8             2.359375
# sex                     int64           int8             2.359375
# tipo_de_dor             int64           int8             2.359375
# pres_art_repous         int64          int16             2.359375
# colest                  int64          int16             2.359375
# acuc_sang_jejum         int64           int8             2.359375
# eletrc_desc             int64           int8             2.359375
# max_frq_card            int64          int16             2.359375
# ang_indz_exerc          int64           int8             2.359375
# ST_indz_exerc         float64           None             2.359375
# pico_ST_exerc           int64           int8             2.359375
# num_vasos               int64           int8             2.359375
# talassemia              int64           int8             2.359375
# ...

# %% [markdown]
# Como podemos observar o padrão do pandas não é a melhor escolha. Os ganhos no uso da memória pra esse dataset não é tão significante por se tratar de uma base de dados pequena. Mas por boas práticas adotaremos a sugestão do dtype_diet.
#
# *As we can see the pandas pattern is not the best choice. The gains in memory usage for this dataset are not that significant because it is a small database. But for good practices we will adopt dtype_diet suggestion*

# %%
# salvando os tipos que queremos em um novo objeto
# saving the types we want in a new object
optmized_df = report_on_dataframe(df_heart, unit="MB")

# Utilizamos a otimização para transformar as colunas do 'df_heart' nas colunas de proposed_df
# We use the optimization to transform the 'df heart' columns into the proposed_df columns
heart_optimized = optimize_dtypes(df_heart, optmized_df)

# %% [markdown]
# Quando comparando os datasets, esse agora ocupa apenas 26% da memória que o primeiro, com as configurações padrão do pandas, usaria.
#
# *When comparing the datasets, this one now takes up only 26% of the memory that the first one, with default pandas settings, would use.*

# %%
heart_optimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              302 non-null    int8
#  1   sex              302 non-null    int8
#  2   tipo_de_dor      302 non-null    int8
#  3   pres_art_repous  302 non-null    int16
#  4   colest           302 non-null    int16
#  5   acuc_sang_jejum  302 non-null    int8
#  6   eletrc_desc      302 non-null    int8
#  7   max_frq_card     302 non-null    int16
#  8   ang_indz_exerc   302 non-null    int8
#  9   ST_indz_exerc    302 non-null    float64
#  10  pico_ST_exerc    302 non-null    int8
#  11  num_vasos        302 non-null    int8
#  12  talassemia       302 non-null    int8
#  13  output           302 non-null    int8
# dtypes: float64(1), int16(3), int8(10)
# memory usage: 9.4 KB

# %%
# Após verificar que a transformação dos tipos foi realizada com sucesso, 
# vamos aplicar ao dataframe original
# After verifying that the type transformation was successful, 
# let's apply it to the original dataframe
df_heart = heart_optimized.copy()

# %% [markdown]
# Criando listas com variáveis numéricas e categóricas
#
# *Creating lists with numerical and categorical variables*

# %%
num = ['age', 'pres_art_repous', 'colest', 'max_frq_card', 'ST_indz_exerc']

cat = ['sex', 'tipo_de_dor', 'ang_indz_exerc', 'num_vasos', 'acuc_sang_jejum', 
       'eletrc_desc', 'pico_ST_exerc', 'talassemia', 'output']

# %% [markdown]
# ### Plotly
# O Plotly será usado para fazer algumas análises univariadas.
#
# *Plotly will be used to do some univariate analysis.*

# %%
# alterando o tipo dos dados de algumas features apenas para essa parte da análise
# changing the data type of some features just for that part of the analysis

df_heart_cat = pd.DataFrame(df_heart).copy()
df_heart_cat[cat] = df_heart_cat[cat].astype(str)

table_cat = ff.create_table(df_heart_cat.describe(include=['O']).T, index=True, index_title='Categorical columns')
for i in range(len(table_cat.layout.annotations)):
    table_cat.layout.annotations[i].font.size = 9
    
table_cat.update_layout(
    title_text = 'Statistics of the categorical columns',
    margin = {'t':50},
    template= "plotly_dark"
)
    
table_cat.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_heart.eletrc_desc.value_counts()
# Out:
# 1    147
# 0    145
# 2      4
# Name: eletrc_desc, dtype: int64

# %% [markdown]
# Alguns pontos chamam a atenção a partir da análise univariada utilizando o Plotly:<br>
# - 68,2% das amostras é do sexo masculino;<br>
# - A maioria (47,35%) dos pacientes não apresenta dor<br>
# - 85,1% das coletas não tinha açucar no sangue em jejum (acuc_sang_jejum); <br>
# - 67,2% das induções por exercício não apresentaram angina (ang_indz_exerc);<br>
# - 57,9 % não apresentar vasos principais;<br>
# - Na descrição fornecida pelo dataset indica um range de quantidade de vasos de 0-3, no entanto temos registros de itens com 4 vasos; <br>
# - Nos eletrocardiográficos em repouso, os pacientes normalmente apresentam hipertrofia ou estão normais, e apenas 1,25% aprensentam anormalidades.
# - Outras feature com número de itens diferentes do que está na descrição são as colunas ```talassemia``` e a ```num_vasos```, que contém dois itens ```0``` e quatro itens ```4```, respectivamente. Segundo pesquisas sobre o dataset no site Kaggle.com se trata de valores ```Null```. Foi decidido removê-las dá análise;<br>
# - Podemos considerar a variável target como balanceada: 54,3-45,7
# ---
#
# *Some points draw attention from the univariate analysis using Plotly*:
# * *68.2% of the samples are male;*
# - *Most (47.35%) patients do not have pain;*
# - *85.1% of the collections had no fasting blood sugar;*
# - *67.2% of exercise inductions had not angina;*
# - *57,9% no major vessels;*
# - *In the description provided by the dataset, it indicates a range of vessels quantity from 0-3, however we have records of items with 4 vessels;*
# - *On resting electrocardiograms, patients usually show hypertrophy or are normal, and only 1.25% show abnormalities;*
# - *Other features with a different number of items than what is in the description are the columns ```talassemia``` and ```num_vasos```, which contain two items ```0``` and four items ```4 ```, respectively. According to research on the dataset on the Kaggle.com site, these are ```Null``` values. It was decided to remove them from analysis;*
# - *We can consider the target variable as balanced: 54.3-45.7.*

# %%
# Drop de linhas com valores nulos
# Drop rows with null values
df_heart = df_heart.drop(df_heart[df_heart.talassemia == 0].index).reset_index(drop=True)
df_heart = df_heart.drop(df_heart[df_heart.num_vasos == 4].index).reset_index(drop=True)
df_heart.shape
# Out:
# (296, 14)

# %% [markdown]
# ### Continuando a análise univariada

# %% [markdown]
# #### Verificando algumas caracteristicas das features numéricas
#
# *Checking some characteristics of numerical features*

# %%
# Age

print(f"Nosso dataset contem pessoas cuja idade vai de {df_heart.age.min()} até\
 {df_heart.age.max()} anos")
# Out:
# Nosso dataset contem pessoas cuja idade vai de 29 até 77 anos

# %%
# maximo de frequência cardíaca  
print(f"A frequência cardíaca máxima dos pacientes vai de {df_heart.max_frq_card.min()}\
 até {df_heart.max_frq_card.max()} Bpm")
# Out:
# A frequência cardíaca máxima dos pacientes vai de 71 até 202 Bpm

# %% [markdown]
# De acordo com a forbes (https://www.forbes.com/health/healthy-aging/normal-heart-rate-by-age/) a frequência cardiaca máxima é como mostrada na tabela abaixo.
#
# *According to forbes (https://www.forbes.com/health/healthy-aging/normal-heart-rate-by-age/) the maximum heart rate is as shown in the table below.*
#
# \begin{array}{|c|c|} \hline
# Age & Average\;maximo\;heart\;rate \\ \hline
# 20 & 200  \\ \hline
# 30 & 190  \\\hline
# 40 & 180\\ \hline
# 50 & 170 \\ \hline
# 60 & 160 \\ \hline
# 70 & 150 \\ \hline
# \end{array}

# %% [markdown]
# As frequências máximas dos pacientes do dataset apresentam uma média da frequencia máxima abaixo do considerado normal, de acordo com a reportagem da Forbes. Entretanto, são duas correlações negativas.

# %%
pontos = [(20, 200), (30,190), (40, 180), (50, 170), (60, 160), (70, 150)]

grafico = sns.relplot(x='age', y='max_frq_card', data=df_heart)
grafico.set_ylabels("Frequência cardíaca Máxima")
grafico.set_xlabels("Age")

sns.regplot(data=df_heart, x='age', y='max_frq_card', ax=grafico.ax)

_ = sns.lineplot(x=[p[0] for p in pontos], y=[p[1] for p in pontos]
                 , color='green', ax=grafico.ax
                 , label='Média da frequência máx normal') 

plt.legend()
plt.show()

# %%
# verificando os coeficientes de correlação e o valor de p
from scipy.stats import pearsonr

coef_corr, p_valor = pearsonr(df_heart['max_frq_card'], df_heart['age'])
print('Coeficiente de correlação:', round(coef_corr, 4), 'e o p-valor:', round(p_valor, 15))

# Teste de hipótese
if p_valor < 0.05:
    print('Há uma correlação significativa entre as variáveis.')
else:
    print('Não há evidência de uma correlação significativa entre as variáveis.')
# Out:
# Coeficiente de correlação: -0.396 e o p-valor: 1.491e-12
# Há uma correlação significativa entre as variáveis.

# %%
# correlação entre os valores forbes
coef_corr, p_valor = pearsonr(x=[p[0] for p in pontos], y=[p[1] for p in pontos])
print('Coeficiente de correlação:', round(coef_corr, 4), 'e o p-valor:', p_valor)

# Teste de hipótese
if p_valor < 0.05:
    print('Há uma correlação significativa entre as variáveis.')
else:
    print('Não há evidência de uma correlação significativa entre as variáveis.')
# Out:
# Coeficiente de correlação: -1.0 e o p-valor: 0.0
# Há uma correlação significativa entre as variáveis.

# %%
fig, axes = plt.subplots(3, 2, figsize=(16, 8))

_ = sns.boxplot(data=df_heart, x = 'output', y='max_frq_card', ax=axes[0][0])
_ = sns.boxplot(data=df_heart, x = 'output', y='ST_indz_exerc', ax=axes[0][1])
_ = sns.boxplot(data=df_heart, x = 'output', y='pres_art_repous', ax=axes[1][0])
_ = sns.boxplot(data=df_heart, x = 'output', y='colest', ax=axes[1][1])
_ = sns.boxplot(data=df_heart, x = 'output', y='age', ax=axes[2][0])

_ = fig.tight_layout()

# %% [markdown]
# Aparentemente, a máxima frequencia cardíaca, a idade e a depressão de ST induzida por exercício em relação ao repouso parecem ter alguma relação com ter maiores ou menores chances de ter um ataque cardíaco.
#
# *Apparently, maximum heart rate, age, and exercise-induced ST depression relative to rest seem to have some relationship with being more or less likely to have a heart attack.*

# %% [markdown]
# ### Análise bivariada
# *Bivariate analysis*

# %% [markdown]
# Nas mulheres há uma taxa de 74,7% com mais chances de ter um ataque cardíaco, enquanto que nos homens a variação é menor e apenas 44,3% tem mais chance de ter um ataque.<br>
# *In women there is a rate of 74.7% more likely to have a heart attack, while in men the variation is smaller and only 44.3% are more likely to have an attack.*
#
# ---

# %%
palette = {0: 'b', 1:'r'}
labels = ['Less chance', 'More chance']

fig = plt.figure(figsize=(20,18))
gs = fig.add_gridspec(4,4)
gs.update(wspace=0.5, hspace=1)

ax_text = fig.add_subplot(gs[0,0])
ax0 = fig.add_subplot(gs[0,1])
ax0.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax1 = fig.add_subplot(gs[0,2])
ax1.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax2 = fig.add_subplot(gs[0,3])
ax2.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax3 = fig.add_subplot(gs[1,0])
ax3.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax4 = fig.add_subplot(gs[1,1])
ax4.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax5 = fig.add_subplot(gs[1,2])
ax5.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax6 = fig.add_subplot(gs[1,3])
ax6.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax7 = fig.add_subplot(gs[2,0])
ax7.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax8 = fig.add_subplot(gs[2,1])
ax8.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax9 = fig.add_subplot(gs[2,2])
ax9.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax10 = fig.add_subplot(gs[2,3])
ax10.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax11 = fig.add_subplot(gs[3,0])
ax11.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
ax12 = fig.add_subplot(gs[3,1])
ax12.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))

for i in ["top","left","right", 'bottom']:
    ax_text.spines[i].set_visible(False)

ax_text.set_xticklabels([])
ax_text.set_yticklabels([])
ax_text.tick_params(left=False, bottom=False)

g0 = sns.kdeplot(ax = ax0, x = 'age', data = df_heart, hue = 'output', palette = palette, legend=False)

g1 = sns.countplot(ax = ax1, x = 'sex', data = df_heart, hue = 'output', palette = palette)
g1.legend([],[], frameon=False)
g1.set_xticks(np.arange(2), ['Female', 'Male'])
g1.set_ylim(0, 130)
for container in g1.containers: # precisa do matplotlib atualizado / need updated matplotlib
    g1.bar_label(container)

handles, _ = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc=(0.075, 0.825))
fig.suptitle('Bivariate Analysis', fontsize=20)

g2 = sns.kdeplot(ax = ax2, x = 'tipo_de_dor', data = df_heart, hue = 'output', palette = palette, legend=False)
g2.set_xticks(np.arange(4), ['asymptomatic: 0', 'typical angina: 1', 'atypical angina: 2', 'non-anginal pain: 3'], rotation=90)

g3 = sns.kdeplot(ax = ax3, x = 'pres_art_repous', data = df_heart, hue = 'output', palette = palette, legend=False)

g4 = sns.kdeplot(ax = ax4, x = 'colest', data = df_heart, hue = 'output', palette = palette, legend=False)

g5 = sns.kdeplot(ax=ax5, x = 'acuc_sang_jejum', data = df_heart, hue = 'output', palette = palette, legend=False)
g5.set_xticks(np.arange(2), ['False: 0', 'True: 1'], rotation=90)

g6 = sns.kdeplot(ax=ax6, x = 'eletrc_desc', data = df_heart, hue = 'output', palette = palette, legend=False)
g6.set_xticks(np.arange(3), ['hypertrophy: 0', 'normal: 1', 'wave abnormality: 2'], rotation=90)

g7 = sns.kdeplot(ax=ax7, x = 'max_frq_card', data = df_heart, hue = 'output', palette = palette, legend=False)

g8 = sns.kdeplot(ax=ax8, x = 'ang_indz_exerc', data = df_heart, hue = 'output', palette = palette, legend=False)
g8.set_xticks(np.arange(2), ['No: 0', 'Yes: 1'], rotation=90)

g9 = sns.kdeplot(ax=ax9, x = 'ST_indz_exerc', data = df_heart, hue = 'output', palette = palette, legend=False)

g10 = sns.kdeplot(ax=ax10, x = 'pico_ST_exerc', data = df_heart, hue = 'output', palette = palette, legend=False)
g10.set_xticks(np.arange(3), ['upsloping: 0', 'flat: 1', 'downsloping: 2'], rotation=90)

g11 = sns.kdeplot(ax=ax11, x = 'num_vasos', data = df_heart, hue = 'output', palette = palette, legend=False)
g11.set_xticks(np.arange(0,4))

g12 = sns.kdeplot(ax=ax12, x = 'talassemia', data = df_heart, hue = 'output', palette = palette, legend=False)
g12.set_xticks(np.arange(1,4), ['fixed defect: 1', 'normal: 2', 'reversable defect: 3'], rotation=90)

plt.show()

# %% [markdown]
# ### Verificando a matriz de correlação
#
# ---
# Checking the correlation matrix

# %%
fig = plt.figure(figsize=(10,6))
gs = fig.add_gridspec(1,1)
gs.update(wspace=0.3, hspace=0.15)
ax0 = fig.add_subplot(gs[0,0])

ax0.text(1.5,-0.1,"Correlation Matrix",fontsize=22, fontweight='bold', fontfamily='serif', color="#000000")
df_corr = df_heart.corr().transpose()
mask = np.triu(np.ones_like(df_corr))
sns.heatmap(df_corr,mask=mask,fmt=".1f",annot=True,cmap='coolwarm', vmin=-1, vmax=1, center= 0)
plt.show()

# %% [markdown]
# ### Pontos observados após a etapa de EDA
#
# * Foram constatados valores nulos que estavam "camuflados" de valores normais, um total de 6 linhas foram removidas;
#
# * Não foi constatada relações linear fortes, segundo Ratner (2009 - doi: 10.1057/jt.2009.5) uma correlação linear forte é aquela que aprensenta valores de r entre 0,7 e 1,0 (-0,7 e -1,0);
#
# * Pessoas mais jovens, com idade entre 20-50, aproximadamente, tem maiores chances de ter ataque cardíaco;
#
# * Como já foi mencionado o dataset tem um número de amostras bem maior para homens que para mulheres, e as mulheres apresentam mais chance de ter um ataque;
#
# * Como esperado pessoas assintomáticas tem menos chance e quanto apresenta angina a considera atipica tem maior incidência de pessoas com mais chance de ter um ataque;
#
# * Com frequências cardíacas maiores que 150 apresentam  maiores chances de ter um ataque, e menores que 150 há mais incidência de pessoas com menor chance de ter um ataque;
#
# * Pessoas com número de vasos principais igual a 0 apresentam maiores chance de ter um ataque;
#
# * Pessoas que não apresentam angina induzida por exercícios mostraram ter mais chance de ter um ataque cardiaco;
#
# * Talassemia normal é a que indica maiores chance de ter um ataque cardíaco;
#
# ---
#
# *Points observed after the EDA stage*
#
# * *Null values were found that were "camouflaged" from normal values, a total of 6 rows were removed;*
#
# * *No strong linear relationships were found, according to Ratner (2009 - doi: 10.1057/jt.2009.5) a strong linear correlation is one that presents r values between 0.7 and 1.0 (-0.7 and -1.0);*
#
# * *Younger people, aged approximately 20-50, are more likely to have a heart attack;*
#
# * *As already mentioned, the dataset has a much larger number of samples for men than for women, and women are more likely to have an attack;*
#
# * *As expected, people who are asymptomatic are less likely to have angina and when they consider it atypical, there is a higher incidence of people with a greater chance of having an attack;*
#
# * *With heart rates greater than 150 are more likely to have an attack, and less than 150 there is more incidence of people with less chance of having an attack;*
#
# * *People with a number of main vessels equal to 0 are more likely to have an attack;*
#
# * *People who don't have exercise-induced angina have been shown to be more likely to have a heart attack;*
#
# * *Normal thalassemia is the highest chance of having a heart attack.*

# %%
# export dataset
df_heart.to_csv('/content/drive/MyDrive/Colab_Notebooks/Heart_attack/datasets/processed_data/df_heart_processed.csv', header=True, index=False)
